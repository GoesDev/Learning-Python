# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("dantebarros/transformed-data-from-quinto-andars-platform")

print("Path to dataset files:", path)

# %%
import pandas as pd

# %%
base = pd.read_csv("datasets/quinto_andar_transformed_data.csv")

# %%
base.head()

# %%
base.info()

# %%
base.isnull().sum()

# %%
base[base.bairro == 'Liberdade']
# Out:
#                                                     url     bairro  aluguel  \
# 0     https://www.quintoandar.com.br/imovel/89332996...  Liberdade   1900.0
# 3     https://www.quintoandar.com.br/imovel/89337065...  Liberdade   1850.0
# 21    https://www.quintoandar.com.br/imovel/89336421...  Liberdade    600.0
# 43    https://www.quintoandar.com.br/imovel/89336704...  Liberdade   1200.0
# 65    https://www.quintoandar.com.br/imovel/89299049...  Liberdade    600.0
# ...                                                 ...        ...      ...
# 2694  https://www.quintoandar.com.br/imovel/89325487...  Liberdade   1080.0
# 2716  https://www.quintoandar.com.br/imovel/89292341...  Liberdade   1200.0
# 2745  https://www.quintoandar.com.br/imovel/89333914...  Liberdade   2500.0
# 2756  https://www.quintoandar.com.br/imovel/89337772...  Liberdade    911.0
# 2760  https://www.quintoandar.com.br/imovel/89337654...  Liberdade   1300.0
#
# ...

# %%
base.loc[base.condominio.isnull()]
# Out:
#                                                     url      bairro  aluguel  \
# 987   https://www.quintoandar.com.br/imovel/89288689...  Bela Vista   2960.0
# 1391  https://www.quintoandar.com.br/imovel/89310205...    Perdizes   5200.0
# 1527  https://www.quintoandar.com.br/imovel/89310896...   Aclimação   3000.0
# 1801  https://www.quintoandar.com.br/imovel/89284189...    Ipiranga   2600.0
# 2287  https://www.quintoandar.com.br/imovel/89288795...    Ipiranga   1000.0
# 2387  https://www.quintoandar.com.br/imovel/89288796...    Ipiranga   1375.0
# 2751  https://www.quintoandar.com.br/imovel/89288796...    Ipiranga   1375.0
#
#       condominio    iptu  seguro_incendio  taxa_serviço   total  metragem  \
# 987          NaN   125.0             49.0          59.0  3193.0     100.0
# 1391         NaN  1030.0             86.0         104.0  6420.0     220.0
# 1527         NaN   158.0             50.0          60.0  3268.0      90.0
# ...

# %%
base.loc[base.condominio.isnull(), 'condominio'] = 0

# %%
base[base.iptu.isnull()]

# %%
base = base.dropna(axis=0)

# %%
base.shape
